# %%
from pydub import AudioSegment
import os
import subprocess
import sys
import ffmpeg

# %% [markdown]
# # File preprocessing

# %% [markdown]
# 1. Select all files in folder (folder = full TV show)
# 2. Convert all video files to mp4, keeping name
# 4. Export files to other folder

# %%
# Make paths for needed folders

def make_audio_path(folder):
    """ Make paths for all Audio files of TV shows in a folder"""
    # Create empty path names list
    path_names = []
    for file in os.scandir(folder):
        # Append path name for TV show + Video
        path_names.append(os.path.join(file.path + "/Audio"))
    return path_names

def make_video_path(folder):
    """ Make paths for all Video files of TV shows in a folder"""
    # Create empty path names list
    path_names = []
    for file in os.scandir(folder):
        # Append path name for TV show + Video
        path_names.append(os.path.join(file.path + "/Video"))
    return path_names


tv_shows = '/home/ada/Documents/DTA/Thesis/Data/TV_shows/'
Men = tv_shows + 'Men/'
Women = tv_shows + 'Women/'

# Men
audio_paths_Men = make_audio_path(Men)
video_paths_Men = make_video_path(Men)

# Women
audio_paths_Women = make_audio_path(Women)
video_paths_Women = make_video_path(Women)

# %%
def extract_audio(video_folders, audio_folders):
  # Iterate over the video folders and extract the audio from all the video files
  for video_folder, audio_folder in zip(video_folders, audio_folders):
    # Check if the audio folder exists, create it if it doesn't
    if not os.path.exists(audio_folder):
      os.makedirs(audio_folder)

    # Get the list of video files in the video folder
    video_files = [os.path.join(video_folder, f) for f in os.listdir(video_folder) if f.endswith('.mp4') or f.endswith('.mkv') or f.endswith('.avi')]

    # Iterate over the video files and extract the audio
    for video_file in video_files:
      print(video_file)
      audio_file = os.path.join(audio_folder, os.path.splitext(os.path.basename(video_file))[0] + 'audio.mp4')
      subprocess.run(['ffmpeg', '-i', video_file, '-y', '-c', 'copy', '-map', '0:a', '-f', 'mp4', audio_file])


extract_audio(video_paths_Men, audio_paths_Men)
# Out:
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E06.HDTV.x264-ASAP.mp4
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E06.HDTV.x264-ASAP.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: mp42isom
#     creation_time   : 2011-09-08T11:43:25.000000Z
#   Duration: 00:55:43.59, start: 0.000000, bitrate: 1052 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709/unknown/unknown), 720x404 [SAR 404:405 DAR 16:9], 923 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2011-09-08T11:43:25.000000Z
#       encoder         : x264
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 120 kb/s (default)
#     Metadata:
#       creation_time   : 2011-09-08T11:43:25.000000Z
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S02E06.HDTV.x264-ASAPaudio.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: mp42isom
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 120 kb/s (default)
#     Metadata:
#       creation_time   : 2011-09-08T11:43:25.000000Z
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   49908kB time=00:55:43.61 bitrate= 122.3kbits/s speed=2.79e+03x
# video:0kB audio:49294kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.245102%
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E04.720p.BluRay.450MB.ShAaNiG.mkv
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E04.720p.BluRay.450MB.ShAaNiG.mkv':
#   Metadata:
#     encoder         : libebml v1.3.0 + libmatroska v1.4.0
#     creation_time   : 2014-07-21T18:31:45.000000Z
#   Duration: 00:59:21.80, start: 0.000000, bitrate: 1057 kb/s
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 23.98 fps, 23.98 tbr, 1k tbn, 47.95 tbc (default)
#     Stream #0:1: Audio: aac (HE-AAC), 48000 Hz, stereo, fltp (default)
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.War.of.the.Damned.S03E04.720p.BluRay.450MB.ShAaNiGaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: aac (HE-AAC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   27213kB time=00:59:21.75 bitrate=  62.6kbits/s speed=3.3e+03x
# video:0kB audio:26714kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.868876%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E02.avi
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E02.avi':
#   Metadata:
#     encoder         : Nandub v1.0rc2
#   Duration: 00:53:08.19, start: 0.000000, bitrate: 1437 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 1299 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 125 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S01E02audio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 125 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   49444kB time=00:53:08.11 bitrate= 127.0kbits/s speed=1.84e+03x
# video:0kB audio:48924kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.063634%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E04.avi
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E04.avi':
#   Metadata:
#     encoder         : Nandub v1.0rc2
#   Duration: 00:49:50.36, start: 0.000000, bitrate: 1534 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 1395 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 126 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S01E04audio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 126 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   46646kB time=00:49:50.30 bitrate= 127.8kbits/s speed=1.84e+03x
# video:0kB audio:46158kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.057526%
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E13.avi
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E13.avi':
#   Metadata:
#     encoder         : Nandub v1.0rc2
#   Duration: 00:54:50.20, start: 0.000000, bitrate: 1396 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 1259 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 124 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S01E13audio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   50549kB time=00:54:50.13 bitrate= 125.9kbits/s speed=1.48e+03x
# video:0kB audio:50012kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.073720%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E04.HDTV.XviD-SYS.avi':
#   Metadata:
#     encoder         : VirtualDubMod 1.5.10.2 (build 2540/release)
#   Duration: 00:58:03.24, start: 0.000000, bitrate: 1327 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 1192 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 121 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S02E04.HDTV.XviD-SYSaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 121 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E04.HDTV.XviD-SYS.avi
# size=   52411kB time=00:58:03.21 bitrate= 123.3kbits/s speed=2.7e+03x
# video:0kB audio:51843kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.096485%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E06.720p.BluRay.450MB.ShAaNiG.mkv':
#   Metadata:
#     encoder         : libebml v1.3.0 + libmatroska v1.4.0
#     creation_time   : 2014-07-21T20:30:08.000000Z
#   Duration: 00:57:25.71, start: 0.000000, bitrate: 1094 kb/s
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 23.98 fps, 23.98 tbr, 1k tbn, 47.95 tbc (default)
#     Stream #0:1: Audio: aac (HE-AAC), 48000 Hz, stereo, fltp (default)
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.War.of.the.Damned.S03E06.720p.BluRay.450MB.ShAaNiGaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: aac (HE-AAC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E06.720p.BluRay.450MB.ShAaNiG.mkv
# size=   27378kB time=00:57:25.66 bitrate=  65.1kbits/s speed=5.58e+03x
# video:0kB audio:26894kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.802163%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E02.720p.BluRay.450MB.ShAaNiG.mkv':
#   Metadata:
#     encoder         : libebml v1.3.0 + libmatroska v1.4.0
#     creation_time   : 2014-07-21T17:30:36.000000Z
#   Duration: 00:54:13.41, start: 0.000000, bitrate: 1159 kb/s
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 23.98 fps, 23.98 tbr, 1k tbn, 47.95 tbc (default)
#     Stream #0:1: Audio: aac (HE-AAC), 48000 Hz, stereo, fltp (default)
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.War.of.the.Damned.S03E02.720p.BluRay.450MB.ShAaNiGaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: aac (HE-AAC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E02.720p.BluRay.450MB.ShAaNiG.mkv
# size=   25852kB time=00:54:13.36 bitrate=  65.1kbits/s speed=5.1e+03x
# video:0kB audio:25395kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.798957%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E08.HDTV.x264-ASAP.mp4
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E08.HDTV.x264-ASAP.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2011-09-08T11:43:25.000000Z
#   Duration: 00:56:33.93, start: 0.000000, bitrate: 1003 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709/unknown/unknown), 720x404 [SAR 404:405 DAR 16:9], 882 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2011-09-08T11:43:25.000000Z
#       encoder         : x264
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 113 kb/s (default)
#     Metadata:
#       creation_time   : 2011-09-08T11:43:25.000000Z
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S02E08.HDTV.x264-ASAPaudio.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 113 kb/s (default)
#     Metadata:
#       creation_time   : 2011-09-08T11:43:25.000000Z
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   47837kB time=00:56:33.92 bitrate= 115.5kbits/s speed=3e+03x
# video:0kB audio:47214kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.319400%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E11.avi
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E11.avi':
#   Duration: 00:50:38.23, start: 0.000000, bitrate: 1516 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 1377 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 125 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S01E11audio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 125 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   47216kB time=00:50:38.20 bitrate= 127.3kbits/s speed=2.83e+03x
# video:0kB audio:46720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.061462%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E06.avi
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E06.avi':
#   Metadata:
#     encoder         : VirtualDubMod 1.5.10.2 (build 2540/release)
#   Duration: 00:54:31.78, start: 0.000000, bitrate: 1414 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 1279 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 122 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S01E06audio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 122 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   49522kB time=00:54:31.75 bitrate= 124.0kbits/s speed=3.03e+03x
# video:0kB audio:48988kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.090001%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E02.HDTV.XviD-SYS.avi
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E02.HDTV.XviD-SYS.avi':
#   Metadata:
#     encoder         : VirtualDubMod 1.5.10.2 (build 2540/release)
#   Duration: 00:52:10.25, start: 0.000000, bitrate: 1479 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 1344 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 121 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S02E02.HDTV.XviD-SYSaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 121 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   47002kB time=00:52:10.22 bitrate= 123.0kbits/s speed=1.61e+03x
# video:0kB audio:46491kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.098934%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E09.avi':
#   Metadata:
#     encoder         : Nandub v1.0rc2
#   Duration: 00:50:51.72, start: 0.000000, bitrate: 1505 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 1366 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 126 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S01E09audio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 126 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E09.avi
# size=   47707kB time=00:50:51.64 bitrate= 128.1kbits/s speed=1.49e+03x
# video:0kB audio:47209kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.055167%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E07.HDTV.x264-ASAP.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2011-09-08T11:43:25.000000Z
#   Duration: 00:55:15.56, start: 0.000000, bitrate: 1040 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709/unknown/unknown), 720x404 [SAR 404:405 DAR 16:9], 912 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2011-09-08T11:43:25.000000Z
#       encoder         : x264
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 117 kb/s (default)
#     Metadata:
#       creation_time   : 2011-09-08T11:43:25.000000Z
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S02E07.HDTV.x264-ASAPaudio.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 117 kb/s (default)
#     Metadata:
#       creation_time   : 2011-09-08T11:43:25.000000Z
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E07.HDTV.x264-ASAP.mp4
# size=   48139kB time=00:55:15.58 bitrate= 118.9kbits/s speed=3.22e+03x
# video:0kB audio:47530kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.280455%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E07.720p.BluRay.450MB.ShAaNiG.mkv':
#   Metadata:
#     encoder         : libebml v1.3.0 + libmatroska v1.4.0
#     creation_time   : 2014-07-21T21:24:16.000000Z
#   Duration: 00:55:18.56, start: 0.000000, bitrate: 1136 kb/s
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 23.98 fps, 23.98 tbr, 1k tbn, 47.95 tbc (default)
#     Stream #0:1: Audio: aac (HE-AAC), 48000 Hz, stereo, fltp (default)
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.War.of.the.Damned.S03E07.720p.BluRay.450MB.ShAaNiGaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: aac (HE-AAC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E07.720p.BluRay.450MB.ShAaNiG.mkv
# size=   26369kB time=00:55:18.51 bitrate=  65.1kbits/s speed=5.15e+03x
# video:0kB audio:25904kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.796928%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E01.HDTV.XviD-SYS.avi
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E01.HDTV.XviD-SYS.avi':
#   Metadata:
#     encoder         : VirtualDubMod 1.5.10.2 (build 2540/release)
#   Duration: 00:56:01.20, start: 0.000000, bitrate: 1375 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 1230 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 132 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S02E01.HDTV.XviD-SYSaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 132 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   54816kB time=00:56:01.17 bitrate= 133.6kbits/s speed=2.17e+03x
# video:0kB audio:54268kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.010972%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E12.avi':
#   Metadata:
#     encoder         : MEncoder dev-SVN-r26940
#   Duration: 00:55:08.93, start: 0.000000, bitrate: 1394 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 1234 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 147 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S01E12audio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 147 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S01E12.avi
# size=   60248kB time=00:55:08.90 bitrate= 149.2kbits/s speed=2.21e+03x
# video:0kB audio:59708kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.904737%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E10.720p.BluRay.450MB.ShAaNiG.mkv':
#   Metadata:
#     encoder         : libebml v1.3.0 + libmatroska v1.4.0
#     creation_time   : 2014-07-22T00:10:31.000000Z
#   Duration: 01:00:39.84, start: 0.000000, bitrate: 1150 kb/s
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 23.98 fps, 23.98 tbr, 1k tbn, 47.95 tbc (default)
#     Stream #0:1: Audio: aac (HE-AAC), 48000 Hz, stereo, fltp (default)
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.War.of.the.Damned.S03E10.720p.BluRay.450MB.ShAaNiGaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: aac (HE-AAC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E10.720p.BluRay.450MB.ShAaNiG.mkv
# size=   28924kB time=01:00:39.79 bitrate=  65.1kbits/s speed=2.98e+03x
# video:0kB audio:28412kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.800517%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E03.HDTV.XviD-ASAP.avi':
#   Metadata:
#     encoder         : Some super fast AVI muxer
#   Duration: 00:53:57.65, start: 0.000000, bitrate: 1424 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 1277 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 134 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.S02E03.HDTV.XviD-ASAPaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 134 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.S02E03.HDTV.XviD-ASAP.avi
# size=   53572kB time=00:53:57.62 bitrate= 135.5kbits/s speed=2.64e+03x
# video:0kB audio:53043kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.996321%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E03.720p.BluRay.450MB.ShAaNiG.mkv':
#   Metadata:
#     encoder         : libebml v1.3.0 + libmatroska v1.4.0
#     creation_time   : 2014-07-21T15:44:57.000000Z
#   Duration: 00:58:33.76, start: 0.000000, bitrate: 1072 kb/s
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 23.98 fps, 23.98 tbr, 1k tbn, 47.95 tbc (default)
#     Stream #0:1: Audio: aac (HE-AAC), 48000 Hz, stereo, fltp (default)
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.War.of.the.Damned.S03E03.720p.BluRay.450MB.ShAaNiGaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: aac (HE-AAC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E03.720p.BluRay.450MB.ShAaNiG.mkv
# size=   27919kB time=00:58:33.71 bitrate=  65.1kbits/s speed=3.67e+03x
# video:0kB audio:27425kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.800718%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E01.720p.BluRay.450MB.ShAaNiG.mkv':
#   Metadata:
#     encoder         : libebml v1.3.0 + libmatroska v1.4.0
#     creation_time   : 2014-07-21T16:34:54.000000Z
#   Duration: 00:51:27.65, start: 0.000000, bitrate: 1221 kb/s
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 23.98 fps, 23.98 tbr, 1k tbn, 47.95 tbc (default)
#     Stream #0:1: Audio: aac (HE-AAC), 48000 Hz, stereo, fltp (default)
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Audio/Spartacus.War.of.the.Damned.S03E01.720p.BluRay.450MB.ShAaNiGaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: aac (HE-AAC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Spartacus/Video/Spartacus.War.of.the.Damned.S03E01.720p.BluRay.450MB.ShAaNiG.mkv
# size=   24533kB time=00:51:27.60 bitrate=  65.1kbits/s speed=4.16e+03x
# video:0kB audio:24099kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.798060%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
# ...
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 0x55c19ef81c80] Could not find codec parameters for stream 2 (Subtitle: hdmv_pgs_subtitle (pgssub)): unspecified size
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 0x55c19ef81c80] Could not find codec parameters for stream 3 (Subtitle: hdmv_pgs_subtitle (pgssub)): unspecified size
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Narcos/Video/Narcos.S01E04.The.Palace.in.Flames.1080p.10bit.BluRay.AAC5.1.HEVC-Vyndros.mkv':
#   Metadata:
#     title           : Narcos.S01E04.1080p.Blu-Ray.REMUX.AVC.DTS-HD.MA.5.1-HDArea
#     encoder         : libebml v1.3.5 + libmatroska v1.4.8
#     creation_time   : 2018-05-19T08:50:01.000000Z
#     Writing frontend: StaxRip v1.7.0.6
#   Duration: 00:43:41.74, start: 0.000000, bitrate: 3621 kb/s
#     Chapter #0:0: start 0.000000, end 223.515000
#     Metadata:
#       title           : 00:00:00.000
#     Chapter #0:1: start 223.515000, end 667.584000
#     Metadata:
#       title           : 00:03:43.515
#     Chapter #0:2: start 667.584000, end 1263.846000
#     Metadata:
#       title           : 00:11:07.584
#     Chapter #0:3: start 1263.846000, end 1703.410000
#     Metadata:
#       title           : 00:21:03.846
#     Chapter #0:4: start 1703.410000, end 2029.736000
#     Metadata:
#       title           : 00:28:23.410
#     Chapter #0:5: start 2029.736000, end 2450.073000
#     Metadata:
#       title           : 00:33:49.736
#     Chapter #0:6: start 2450.073000, end 2621.738000
#     Metadata:
#       title           : 00:40:50.073
#     Stream #0:0: Video: hevc (Main 10), yuv420p10le(tv), 1920x1080, SAR 1:1 DAR 16:9, 23.98 fps, 23.98 tbr, 1k tbn, 23.98 tbc (default)
#     Metadata:
#       BPS             : 3142747
#       BPS-eng         : 3142747
#       DURATION        : 00:43:41.703000000
#       DURATION-eng    : 00:43:41.703000000
#       NUMBER_OF_FRAMES: 62858
#       NUMBER_OF_FRAMES-eng: 62858
#       NUMBER_OF_BYTES : 1029918948
#       NUMBER_OF_BYTES-eng: 1029918948
#       _STATISTICS_WRITING_APP: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_DATE_UTC: 2018-05-19 08:50:01
#       _STATISTICS_WRITING_DATE_UTC-eng: 2018-05-19 08:50:01
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:1(eng): Audio: aac (LC), 48000 Hz, 5.1, fltp (default)
#     Metadata:
#       BPS             : 446632
#       BPS-eng         : 446632
#       DURATION        : 00:43:41.738000000
#       DURATION-eng    : 00:43:41.738000000
#       NUMBER_OF_FRAMES: 122894
#       NUMBER_OF_FRAMES-eng: 122894
#       NUMBER_OF_BYTES : 146369050
#       NUMBER_OF_BYTES-eng: 146369050
#       _STATISTICS_WRITING_APP: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_DATE_UTC: 2018-05-19 08:50:01
#       _STATISTICS_WRITING_DATE_UTC-eng: 2018-05-19 08:50:01
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:2(eng): Subtitle: hdmv_pgs_subtitle
#     Metadata:
#       BPS             : 57919
#       BPS-eng         : 57919
#       DURATION        : 00:42:28.837000000
#       DURATION-eng    : 00:42:28.837000000
#       NUMBER_OF_FRAMES: 1362
#       NUMBER_OF_FRAMES-eng: 1362
#       NUMBER_OF_BYTES : 18453577
#       NUMBER_OF_BYTES-eng: 18453577
#       _STATISTICS_WRITING_APP: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_DATE_UTC: 2018-05-19 08:50:01
#       _STATISTICS_WRITING_DATE_UTC-eng: 2018-05-19 08:50:01
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:3(eng): Subtitle: hdmv_pgs_subtitle
#     Metadata:
#       BPS             : 15410
#       BPS-eng         : 15410
#       DURATION        : 00:41:16.849000000
#       DURATION-eng    : 00:41:16.849000000
#       NUMBER_OF_FRAMES: 418
#       NUMBER_OF_FRAMES-eng: 418
#       NUMBER_OF_BYTES : 4771064
#       NUMBER_OF_BYTES-eng: 4771064
#       _STATISTICS_WRITING_APP: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_DATE_UTC: 2018-05-19 08:50:01
#       _STATISTICS_WRITING_DATE_UTC-eng: 2018-05-19 08:50:01
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Narcos/Audio/Narcos.S01E04.The.Palace.in.Flames.1080p.10bit.BluRay.AAC5.1.HEVC-Vyndrosaudio.mp4':
#   Metadata:
#     title           : Narcos.S01E04.1080p.Blu-Ray.REMUX.AVC.DTS-HD.MA.5.1-HDArea
#     Writing frontend: StaxRip v1.7.0.6
#     encoder         : Lavf58.45.100
#     Chapter #0:0: start 0.000000, end 223.515000
#     Metadata:
#       title           : 00:00:00.000
#     Chapter #0:1: start 223.515000, end 667.584000
#     Metadata:
#       title           : 00:03:43.515
#     Chapter #0:2: start 667.584000, end 1263.846000
#     Metadata:
#       title           : 00:11:07.584
#     Chapter #0:3: start 1263.846000, end 1703.410000
#     Metadata:
#       title           : 00:21:03.846
#     Chapter #0:4: start 1703.410000, end 2029.736000
#     Metadata:
#       title           : 00:28:23.410
#     Chapter #0:5: start 2029.736000, end 2450.073000
#     Metadata:
#       title           : 00:33:49.736
#     Chapter #0:6: start 2450.073000, end 2621.738000
#     Metadata:
#       title           : 00:40:50.073
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp (default)
#     Metadata:
#       BPS             : 446632
#       BPS-eng         : 446632
#       DURATION        : 00:43:41.738000000
#       DURATION-eng    : 00:43:41.738000000
#       NUMBER_OF_FRAMES: 122894
#       NUMBER_OF_FRAMES-eng: 122894
#       NUMBER_OF_BYTES : 146369050
#       NUMBER_OF_BYTES-eng: 146369050
#       _STATISTICS_WRITING_APP: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_DATE_UTC: 2018-05-19 08:50:01
#       _STATISTICS_WRITING_DATE_UTC-eng: 2018-05-19 08:50:01
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  143821kB time=00:43:41.71 bitrate= 449.4kbits/s speed=1.69e+03x
# video:0kB audio:142939kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.617088%
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Narcos/Video/Narcos.S01E07.You.Will.Cry.Tears.of.Blood.1080p.10bit.BluRay.AAC5.1.HEVC-Vyndros.mkv
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 0x55d4bdc04c80] Could not find codec parameters for stream 2 (Subtitle: hdmv_pgs_subtitle (pgssub)): unspecified size
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 0x55d4bdc04c80] Could not find codec parameters for stream 3 (Subtitle: hdmv_pgs_subtitle (pgssub)): unspecified size
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Narcos/Video/Narcos.S01E07.You.Will.Cry.Tears.of.Blood.1080p.10bit.BluRay.AAC5.1.HEVC-Vyndros.mkv':
#   Metadata:
#     title           : Narcos.S01E07.1080p.Blu-Ray.REMUX.AVC.DTS-HD.MA.5.1-HDArea
#     encoder         : libebml v1.3.5 + libmatroska v1.4.8
#     creation_time   : 2018-05-20T05:39:53.000000Z
#     Writing frontend: StaxRip v1.7.0.6
#   Duration: 00:50:38.08, start: 0.000000, bitrate: 3659 kb/s
#     Chapter #0:0: start 0.000000, end 397.647000
#     Metadata:
#       title           : 00:00:00.000
#     Chapter #0:1: start 397.647000, end 848.723000
#     Metadata:
#       title           : 00:06:37.647
#     Chapter #0:2: start 848.723000, end 1252.001000
#     Metadata:
#       title           : 00:14:08.723
#     Chapter #0:3: start 1252.001000, end 1803.677000
#     Metadata:
#       title           : 00:20:52.001
#     Chapter #0:4: start 1803.677000, end 2181.721000
#     Metadata:
#       title           : 00:30:03.677
#     Chapter #0:5: start 2181.721000, end 2516.723000
#     Metadata:
#       title           : 00:36:21.721
#     Chapter #0:6: start 2516.723000, end 3038.077000
#     Metadata:
#       title           : 00:41:56.723
#     Stream #0:0: Video: hevc (Main 10), yuv420p10le(tv), 1920x1080, SAR 1:1 DAR 16:9, 23.98 fps, 23.98 tbr, 1k tbn, 23.98 tbc (default)
#     Metadata:
#       BPS             : 3181077
#       BPS-eng         : 3181077
#       DURATION        : 00:50:38.077000000
#       DURATION-eng    : 00:50:38.077000000
#       NUMBER_OF_FRAMES: 72841
#       NUMBER_OF_FRAMES-eng: 72841
#       NUMBER_OF_BYTES : 1208044748
#       NUMBER_OF_BYTES-eng: 1208044748
#       _STATISTICS_WRITING_APP: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_DATE_UTC: 2018-05-20 05:39:53
#       _STATISTICS_WRITING_DATE_UTC-eng: 2018-05-20 05:39:53
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:1(eng): Audio: aac (LC), 48000 Hz, 5.1, fltp (default)
#     Metadata:
#       BPS             : 447701
#       BPS-eng         : 447701
#       DURATION        : 00:50:38.058000000
#       DURATION-eng    : 00:50:38.058000000
#       NUMBER_OF_FRAMES: 142409
#       NUMBER_OF_FRAMES-eng: 142409
#       NUMBER_OF_BYTES : 170017902
#       NUMBER_OF_BYTES-eng: 170017902
#       _STATISTICS_WRITING_APP: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_DATE_UTC: 2018-05-20 05:39:53
#       _STATISTICS_WRITING_DATE_UTC-eng: 2018-05-20 05:39:53
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:2(eng): Subtitle: hdmv_pgs_subtitle
#     Metadata:
#       BPS             : 41452
#       BPS-eng         : 41452
#       DURATION        : 00:49:14.618000000
#       DURATION-eng    : 00:49:14.618000000
#       NUMBER_OF_FRAMES: 1242
#       NUMBER_OF_FRAMES-eng: 1242
#       NUMBER_OF_BYTES : 15309683
#       NUMBER_OF_BYTES-eng: 15309683
#       _STATISTICS_WRITING_APP: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_DATE_UTC: 2018-05-20 05:39:53
#       _STATISTICS_WRITING_DATE_UTC-eng: 2018-05-20 05:39:53
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:3(eng): Subtitle: hdmv_pgs_subtitle
#     Metadata:
#       BPS             : 27360
#       BPS-eng         : 27360
#       DURATION        : 00:49:14.535000000
#       DURATION-eng    : 00:49:14.535000000
#       NUMBER_OF_FRAMES: 868
#       NUMBER_OF_FRAMES-eng: 868
#       NUMBER_OF_BYTES : 10104832
#       NUMBER_OF_BYTES-eng: 10104832
#       _STATISTICS_WRITING_APP: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_DATE_UTC: 2018-05-20 05:39:53
#       _STATISTICS_WRITING_DATE_UTC-eng: 2018-05-20 05:39:53
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Men/Narcos/Audio/Narcos.S01E07.You.Will.Cry.Tears.of.Blood.1080p.10bit.BluRay.AAC5.1.HEVC-Vyndrosaudio.mp4':
#   Metadata:
#     title           : Narcos.S01E07.1080p.Blu-Ray.REMUX.AVC.DTS-HD.MA.5.1-HDArea
#     Writing frontend: StaxRip v1.7.0.6
#     encoder         : Lavf58.45.100
#     Chapter #0:0: start 0.000000, end 397.647000
#     Metadata:
#       title           : 00:00:00.000
#     Chapter #0:1: start 397.647000, end 848.723000
#     Metadata:
#       title           : 00:06:37.647
#     Chapter #0:2: start 848.723000, end 1252.001000
#     Metadata:
#       title           : 00:14:08.723
#     Chapter #0:3: start 1252.001000, end 1803.677000
#     Metadata:
#       title           : 00:20:52.001
#     Chapter #0:4: start 1803.677000, end 2181.721000
#     Metadata:
#       title           : 00:30:03.677
#     Chapter #0:5: start 2181.721000, end 2516.723000
#     Metadata:
#       title           : 00:36:21.721
#     Chapter #0:6: start 2516.723000, end 3038.077000
#     Metadata:
#       title           : 00:41:56.723
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp (default)
#     Metadata:
#       BPS             : 447701
#       BPS-eng         : 447701
#       DURATION        : 00:50:38.058000000
#       DURATION-eng    : 00:50:38.058000000
#       NUMBER_OF_FRAMES: 142409
#       NUMBER_OF_FRAMES-eng: 142409
#       NUMBER_OF_BYTES : 170017902
#       NUMBER_OF_BYTES-eng: 170017902
#       _STATISTICS_WRITING_APP: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v20.0.0 ('I Am The Sun') 64-bit
#       _STATISTICS_WRITING_DATE_UTC: 2018-05-20 05:39:53
#       _STATISTICS_WRITING_DATE_UTC-eng: 2018-05-20 05:39:53
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=  167055kB time=00:50:38.03 bitrate= 450.5kbits/s speed=1.57e+03x
# video:0kB audio:166033kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.615412%

# %%
extract_audio(video_paths_Women, audio_paths_Women)
# Out:
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S01E03.Chapter.Three.720p.WEB-DL.2CH.x265.HEVC-PSA.mkv
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S01E03.Chapter.Three.720p.WEB-DL.2CH.x265.HEVC-PSA.mkv':
#   Metadata:
#     title           : PSArips.com | Jane.the.Virgin.S01E03.Chapter.Three.720p.WEB-DL.2CH.x265.HEVC-PSA
#     encoder         : libebml v1.3.1 + libmatroska v1.4.2
#     creation_time   : 2015-05-28T19:21:54.000000Z
#   Duration: 00:42:11.05, start: 0.000000, bitrate: 424 kb/s
#     Stream #0:0: Video: hevc (Main), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 23.98 fps, 23.98 tbr, 1k tbn, 23.98 tbc (default)
#     Metadata:
#       BPS             : 358791
#       BPS-eng         : 358791
#       DURATION        : 00:42:10.945000000
#       DURATION-eng    : 00:42:10.945000000
#       NUMBER_OF_FRAMES: 60682
#       NUMBER_OF_FRAMES-eng: 60682
#       NUMBER_OF_BYTES : 113510190
#       NUMBER_OF_BYTES-eng: 113510190
#       _STATISTICS_WRITING_APP: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-28 19:21:54
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-28 19:21:54
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:1(eng): Audio: aac (HE-AAC), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       title           : Stereo
#       BPS             : 64000
#       BPS-eng         : 64000
#       DURATION        : 00:42:10.944000000
#       DURATION-eng    : 00:42:10.944000000
#       NUMBER_OF_FRAMES: 59319
#       NUMBER_OF_FRAMES-eng: 59319
#       NUMBER_OF_BYTES : 20247553
#       NUMBER_OF_BYTES-eng: 20247553
#       _STATISTICS_WRITING_APP: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-28 19:21:54
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-28 19:21:54
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:2: Subtitle: subrip (default)
#     Metadata:
#       BPS             : 84
#       BPS-eng         : 84
#       DURATION        : 00:41:38.927000000
#       DURATION-eng    : 00:41:38.927000000
#       NUMBER_OF_FRAMES: 880
#       NUMBER_OF_FRAMES-eng: 880
#       NUMBER_OF_BYTES : 26550
#       NUMBER_OF_BYTES-eng: 26550
#       _STATISTICS_WRITING_APP: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-28 19:21:54
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-28 19:21:54
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Audio/Jane.the.Virgin.S01E03.Chapter.Three.720p.WEB-DL.2CH.x265.HEVC-PSAaudio.mp4':
#   Metadata:
#     title           : PSArips.com | Jane.the.Virgin.S01E03.Chapter.Three.720p.WEB-DL.2CH.x265.HEVC-PSA
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       title           : Stereo
#       BPS             : 64000
#       BPS-eng         : 64000
#       DURATION        : 00:42:10.944000000
#       DURATION-eng    : 00:42:10.944000000
#       NUMBER_OF_FRAMES: 59319
#       NUMBER_OF_FRAMES-eng: 59319
#       NUMBER_OF_BYTES : 20247553
#       NUMBER_OF_BYTES-eng: 20247553
#       _STATISTICS_WRITING_APP: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-28 19:21:54
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-28 19:21:54
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   20128kB time=00:42:10.90 bitrate=  65.1kbits/s speed=5.59e+03x
# video:0kB audio:19773kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.794963%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S01E17.Chapter.Seventeen.720p.WEB-DL.2CH.x265.HEVC-PSA.mkv':
#   Metadata:
#     title           : PSArips.com | Jane.the.Virgin.S01E17.Chapter.Seventeen.720p.WEB-DL.2CH.x265.HEVC-PSA
#     encoder         : libebml v1.3.1 + libmatroska v1.4.2
#     creation_time   : 2015-05-09T12:10:06.000000Z
#   Duration: 00:42:33.95, start: 0.000000, bitrate: 558 kb/s
#     Stream #0:0: Video: hevc (Main), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 23.98 fps, 23.98 tbr, 1k tbn, 23.98 tbc (default)
#     Metadata:
#       BPS             : 492288
#       BPS-eng         : 492288
#       DURATION        : 00:42:33.843000000
#       DURATION-eng    : 00:42:33.843000000
#       NUMBER_OF_FRAMES: 61231
#       NUMBER_OF_FRAMES-eng: 61231
#       NUMBER_OF_BYTES : 157153416
#       NUMBER_OF_BYTES-eng: 157153416
#       _STATISTICS_WRITING_APP: mkvmerge v7.8.0 ('River Man') 64bit built on Mar 27 2015 16:31:37
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.8.0 ('River Man') 64bit built on Mar 27 2015 16:31:37
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-09 12:10:06
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-09 12:10:06
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:1(eng): Audio: aac (HE-AAC), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       title           : Stereo
#       BPS             : 64000
#       BPS-eng         : 64000
#       DURATION        : 00:42:33.856000000
#       DURATION-eng    : 00:42:33.856000000
#       NUMBER_OF_FRAMES: 59856
#       NUMBER_OF_FRAMES-eng: 59856
#       NUMBER_OF_BYTES : 20430849
#       NUMBER_OF_BYTES-eng: 20430849
#       _STATISTICS_WRITING_APP: mkvmerge v7.8.0 ('River Man') 64bit built on Mar 27 2015 16:31:37
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.8.0 ('River Man') 64bit built on Mar 27 2015 16:31:37
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-09 12:10:06
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-09 12:10:06
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:2: Subtitle: subrip (default)
#     Metadata:
#       BPS             : 97
#       BPS-eng         : 97
#       DURATION        : 00:42:04.152000000
#       DURATION-eng    : 00:42:04.152000000
#       NUMBER_OF_FRAMES: 1041
#       NUMBER_OF_FRAMES-eng: 1041
#       NUMBER_OF_BYTES : 30835
#       NUMBER_OF_BYTES-eng: 30835
#       _STATISTICS_WRITING_APP: mkvmerge v7.8.0 ('River Man') 64bit built on Mar 27 2015 16:31:37
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.8.0 ('River Man') 64bit built on Mar 27 2015 16:31:37
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-09 12:10:06
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-09 12:10:06
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Audio/Jane.the.Virgin.S01E17.Chapter.Seventeen.720p.WEB-DL.2CH.x265.HEVC-PSAaudio.mp4':
#   Metadata:
#     title           : PSArips.com | Jane.the.Virgin.S01E17.Chapter.Seventeen.720p.WEB-DL.2CH.x265.HEVC-PSA
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       title           : Stereo
#       BPS             : 64000
#       BPS-eng         : 64000
#       DURATION        : 00:42:33.856000000
#       DURATION-eng    : 00:42:33.856000000
#       NUMBER_OF_FRAMES: 59856
#       NUMBER_OF_FRAMES-eng: 59856
#       NUMBER_OF_BYTES : 20430849
#       NUMBER_OF_BYTES-eng: 20430849
#       _STATISTICS_WRITING_APP: mkvmerge v7.8.0 ('River Man') 64bit built on Mar 27 2015 16:31:37
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.8.0 ('River Man') 64bit built on Mar 27 2015 16:31:37
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-09 12:10:06
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-09 12:10:06
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S01E17.Chapter.Seventeen.720p.WEB-DL.2CH.x265.HEVC-PSA.mkv
# size=   20310kB time=00:42:33.81 bitrate=  65.2kbits/s speed=5.44e+03x
# video:0kB audio:19952kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.795794%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S01E10.Chapter.Ten.720p.WEB-DL.2CH.x265.HEVC-PSA.mkv':
#   Metadata:
#     title           : PSArips.com | Jane.the.Virgin.S01E10.Chapter.Ten.720p.WEB-DL.2CH.x265.HEVC-PSA
#     encoder         : libebml v1.3.1 + libmatroska v1.4.2
#     creation_time   : 2015-01-21T10:34:06.000000Z
#   Duration: 00:42:26.94, start: 0.000000, bitrate: 629 kb/s
#     Stream #0:0: Video: hevc (Main), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 24 fps, 24 tbr, 1k tbn, 24 tbc (default)
#     Metadata:
#       BPS             : 579107
#       BPS-eng         : 579107
#       DURATION        : 00:42:26.839000000
#       DURATION-eng    : 00:42:26.839000000
#       NUMBER_OF_FRAMES: 61063
#       NUMBER_OF_FRAMES-eng: 61063
#       NUMBER_OF_BYTES : 184361797
#       NUMBER_OF_BYTES-eng: 184361797
#       _STATISTICS_WRITING_APP: mkvmerge v7.5.0 ('Glass Culture') 64bit built on Jan  4 2015 16:48:44
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.5.0 ('Glass Culture') 64bit built on Jan  4 2015 16:48:44
#       _STATISTICS_WRITING_DATE_UTC: 2015-01-21 10:34:06
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-01-21 10:34:06
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:1(eng): Audio: aac (HE-AAC), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       title           : Stereo
#       BPS             : 48000
#       BPS-eng         : 48000
#       DURATION        : 00:42:26.816000000
#       DURATION-eng    : 00:42:26.816000000
#       NUMBER_OF_FRAMES: 59691
#       NUMBER_OF_FRAMES-eng: 59691
#       NUMBER_OF_BYTES : 15281116
#       NUMBER_OF_BYTES-eng: 15281116
#       _STATISTICS_WRITING_APP: mkvmerge v7.5.0 ('Glass Culture') 64bit built on Jan  4 2015 16:48:44
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.5.0 ('Glass Culture') 64bit built on Jan  4 2015 16:48:44
#       _STATISTICS_WRITING_DATE_UTC: 2015-01-21 10:34:06
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-01-21 10:34:06
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:2: Subtitle: subrip (default)
#     Metadata:
#       BPS             : 98
#       BPS-eng         : 98
#       DURATION        : 00:41:57.846000000
#       DURATION-eng    : 00:41:57.846000000
#       NUMBER_OF_FRAMES: 921
#       NUMBER_OF_FRAMES-eng: 921
#       NUMBER_OF_BYTES : 31059
#       NUMBER_OF_BYTES-eng: 31059
#       _STATISTICS_WRITING_APP: mkvmerge v7.5.0 ('Glass Culture') 64bit built on Jan  4 2015 16:48:44
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.5.0 ('Glass Culture') 64bit built on Jan  4 2015 16:48:44
#       _STATISTICS_WRITING_DATE_UTC: 2015-01-21 10:34:06
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-01-21 10:34:06
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Audio/Jane.the.Virgin.S01E10.Chapter.Ten.720p.WEB-DL.2CH.x265.HEVC-PSAaudio.mp4':
#   Metadata:
#     title           : PSArips.com | Jane.the.Virgin.S01E10.Chapter.Ten.720p.WEB-DL.2CH.x265.HEVC-PSA
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       title           : Stereo
#       BPS             : 48000
#       BPS-eng         : 48000
#       DURATION        : 00:42:26.816000000
#       DURATION-eng    : 00:42:26.816000000
#       NUMBER_OF_FRAMES: 59691
#       NUMBER_OF_FRAMES-eng: 59691
#       NUMBER_OF_BYTES : 15281116
#       NUMBER_OF_BYTES-eng: 15281116
#       _STATISTICS_WRITING_APP: mkvmerge v7.5.0 ('Glass Culture') 64bit built on Jan  4 2015 16:48:44
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.5.0 ('Glass Culture') 64bit built on Jan  4 2015 16:48:44
#       _STATISTICS_WRITING_DATE_UTC: 2015-01-21 10:34:06
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-01-21 10:34:06
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S01E10.Chapter.Ten.720p.WEB-DL.2CH.x265.HEVC-PSA.mkv
# size=   15281kB time=00:42:26.77 bitrate=  49.2kbits/s speed=4.78e+03x
# video:0kB audio:14923kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.396383%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S01E05.Chapter.Five.720p.WEB-DL.2CH.x265.HEVC-PSA.mkv':
#   Metadata:
#     title           : PSArips.com | Jane.the.Virgin.S01E05.Chapter.Five.720p.WEB-DL.2CH.x265.HEVC-PSA
#     encoder         : libebml v1.3.1 + libmatroska v1.4.2
#     creation_time   : 2015-05-28T19:21:57.000000Z
#   Duration: 00:42:05.46, start: 0.000000, bitrate: 434 kb/s
#     Stream #0:0: Video: hevc (Main), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 23.98 fps, 23.98 tbr, 1k tbn, 23.98 tbc (default)
#     Metadata:
#       BPS             : 368414
#       BPS-eng         : 368414
#       DURATION        : 00:42:05.359000000
#       DURATION-eng    : 00:42:05.359000000
#       NUMBER_OF_FRAMES: 60548
#       NUMBER_OF_FRAMES-eng: 60548
#       NUMBER_OF_BYTES : 116297258
#       NUMBER_OF_BYTES-eng: 116297258
#       _STATISTICS_WRITING_APP: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-28 19:21:57
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-28 19:21:57
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:1(eng): Audio: aac (HE-AAC), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       title           : Stereo
#       BPS             : 63999
#       BPS-eng         : 63999
#       DURATION        : 00:42:05.355000000
#       DURATION-eng    : 00:42:05.355000000
#       NUMBER_OF_FRAMES: 59188
#       NUMBER_OF_FRAMES-eng: 59188
#       NUMBER_OF_BYTES : 20202838
#       NUMBER_OF_BYTES-eng: 20202838
#       _STATISTICS_WRITING_APP: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-28 19:21:57
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-28 19:21:57
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:2: Subtitle: subrip (default)
#     Metadata:
#       BPS             : 94
#       BPS-eng         : 94
#       DURATION        : 00:41:36.658000000
#       DURATION-eng    : 00:41:36.658000000
#       NUMBER_OF_FRAMES: 920
#       NUMBER_OF_FRAMES-eng: 920
#       NUMBER_OF_BYTES : 29373
#       NUMBER_OF_BYTES-eng: 29373
#       _STATISTICS_WRITING_APP: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-28 19:21:57
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-28 19:21:57
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Audio/Jane.the.Virgin.S01E05.Chapter.Five.720p.WEB-DL.2CH.x265.HEVC-PSAaudio.mp4':
#   Metadata:
#     title           : PSArips.com | Jane.the.Virgin.S01E05.Chapter.Five.720p.WEB-DL.2CH.x265.HEVC-PSA
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       title           : Stereo
#       BPS             : 63999
#       BPS-eng         : 63999
#       DURATION        : 00:42:05.355000000
#       DURATION-eng    : 00:42:05.355000000
#       NUMBER_OF_FRAMES: 59188
#       NUMBER_OF_FRAMES-eng: 59188
#       NUMBER_OF_BYTES : 20202838
#       NUMBER_OF_BYTES-eng: 20202838
#       _STATISTICS_WRITING_APP: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-28 19:21:57
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-28 19:21:57
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S01E05.Chapter.Five.720p.WEB-DL.2CH.x265.HEVC-PSA.mkv
# size=   20083kB time=00:42:05.31 bitrate=  65.1kbits/s speed=5.18e+03x
# video:0kB audio:19729kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.794238%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S02E19.mkv':
#   Metadata:
#     encoder         : libebml v1.3.3 + libmatroska v1.4.4
#     creation_time   : 2016-06-18T18:44:32.000000Z
#   Duration: 00:42:08.54, start: 0.000000, bitrate: 1289 kb/s
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1280x720, SAR 1:1 DAR 16:9, 23.98 fps, 23.98 tbr, 1k tbn, 47.95 tbc (default)
#     Metadata:
#       BPS             : 1063870
#       BPS-eng         : 1063870
#       DURATION        : 00:42:08.526000000
#       DURATION-eng    : 00:42:08.526000000
#       NUMBER_OF_FRAMES: 60624
#       NUMBER_OF_FRAMES-eng: 60624
#       NUMBER_OF_BYTES : 336253045
#       NUMBER_OF_BYTES-eng: 336253045
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 18:44:32
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 18:44:32
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:1(eng): Audio: ac3, 48000 Hz, 5.1(side), fltp, 224 kb/s
#     Metadata:
#       BPS             : 224000
#       BPS-eng         : 224000
#       DURATION        : 00:42:08.544000000
#       DURATION-eng    : 00:42:08.544000000
#       NUMBER_OF_FRAMES: 79017
#       NUMBER_OF_FRAMES-eng: 79017
#       NUMBER_OF_BYTES : 70799232
#       NUMBER_OF_BYTES-eng: 70799232
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 18:44:32
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 18:44:32
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:2: Subtitle: subrip
#     Metadata:
#       BPS             : 90
#       BPS-eng         : 90
#       DURATION        : 00:41:45.097000000
#       DURATION-eng    : 00:41:45.097000000
#       NUMBER_OF_FRAMES: 1070
#       NUMBER_OF_FRAMES-eng: 1070
#       NUMBER_OF_BYTES : 28478
#       NUMBER_OF_BYTES-eng: 28478
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 18:44:32
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 18:44:32
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# [mp4 @ 0x5626ff8c8600] track 0: codec frame size is not set
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Audio/Jane.the.Virgin.S02E19audio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Audio: ac3 (ac-3 / 0x332D6361), 48000 Hz, 5.1(side), fltp, 224 kb/s
#     Metadata:
#       BPS             : 224000
#       BPS-eng         : 224000
#       DURATION        : 00:42:08.544000000
#       DURATION-eng    : 00:42:08.544000000
#       NUMBER_OF_FRAMES: 79017
#       NUMBER_OF_FRAMES-eng: 79017
#       NUMBER_OF_BYTES : 70799232
#       NUMBER_OF_BYTES-eng: 70799232
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 18:44:32
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 18:44:32
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S02E19.mkv
# size=   69141kB time=00:42:08.51 bitrate= 224.0kbits/s speed=2.24e+03x
# video:0kB audio:69140kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001387%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S02E01.mkv
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S02E01.mkv':
#   Metadata:
#     encoder         : libebml v1.3.3 + libmatroska v1.4.4
#     creation_time   : 2016-06-18T01:05:38.000000Z
#   Duration: 00:42:00.19, start: 0.000000, bitrate: 1293 kb/s
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1280x720, SAR 1:1 DAR 16:9, 23.98 fps, 23.98 tbr, 1k tbn, 47.95 tbc (default)
#     Metadata:
#       BPS             : 1067883
#       BPS-eng         : 1067883
#       DURATION        : 00:42:00.185000000
#       DURATION-eng    : 00:42:00.185000000
#       NUMBER_OF_FRAMES: 60424
#       NUMBER_OF_FRAMES-eng: 60424
#       NUMBER_OF_BYTES : 336408139
#       NUMBER_OF_BYTES-eng: 336408139
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 01:05:38
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 01:05:38
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:1(eng): Audio: ac3, 48000 Hz, 5.1(side), fltp, 224 kb/s
#     Metadata:
#       BPS             : 224000
#       BPS-eng         : 224000
#       DURATION        : 00:42:00.064000000
#       DURATION-eng    : 00:42:00.064000000
#       NUMBER_OF_FRAMES: 78752
#       NUMBER_OF_FRAMES-eng: 78752
#       NUMBER_OF_BYTES : 70561792
#       NUMBER_OF_BYTES-eng: 70561792
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 01:05:38
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 01:05:38
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:2: Subtitle: subrip
#     Metadata:
#       BPS             : 88
#       BPS-eng         : 88
#       DURATION        : 00:41:54.605000000
#       DURATION-eng    : 00:41:54.605000000
#       NUMBER_OF_FRAMES: 1004
#       NUMBER_OF_FRAMES-eng: 1004
#       NUMBER_OF_BYTES : 27732
#       NUMBER_OF_BYTES-eng: 27732
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 01:05:38
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 01:05:38
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# [mp4 @ 0x557165602600] track 0: codec frame size is not set
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Audio/Jane.the.Virgin.S02E01audio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Audio: ac3 (ac-3 / 0x332D6361), 48000 Hz, 5.1(side), fltp, 224 kb/s
#     Metadata:
#       BPS             : 224000
#       BPS-eng         : 224000
#       DURATION        : 00:42:00.064000000
#       DURATION-eng    : 00:42:00.064000000
#       NUMBER_OF_FRAMES: 78752
#       NUMBER_OF_FRAMES-eng: 78752
#       NUMBER_OF_BYTES : 70561792
#       NUMBER_OF_BYTES-eng: 70561792
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 01:05:38
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 01:05:38
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   68909kB time=00:42:00.03 bitrate= 224.0kbits/s speed=1.93e+03x
# video:0kB audio:68908kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001392%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S01E04.Chapter.Four.720p.WEB-DL.2CH.x265.HEVC-PSA.mkv':
#   Metadata:
#     title           : PSArips.com | Jane.the.Virgin.S01E04.Chapter.Four.720p.WEB-DL.2CH.x265.HEVC-PSA
#     encoder         : libebml v1.3.1 + libmatroska v1.4.2
#     creation_time   : 2015-05-28T19:21:55.000000Z
#   Duration: 00:42:32.32, start: 0.000000, bitrate: 453 kb/s
#     Stream #0:0: Video: hevc (Main), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 23.98 fps, 23.98 tbr, 1k tbn, 23.98 tbc (default)
#     Metadata:
#       BPS             : 387579
#       BPS-eng         : 387579
#       DURATION        : 00:42:32.217000000
#       DURATION-eng    : 00:42:32.217000000
#       NUMBER_OF_FRAMES: 61192
#       NUMBER_OF_FRAMES-eng: 61192
#       NUMBER_OF_BYTES : 123648479
#       NUMBER_OF_BYTES-eng: 123648479
#       _STATISTICS_WRITING_APP: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-28 19:21:55
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-28 19:21:55
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:1(eng): Audio: aac (HE-AAC), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       title           : Stereo
#       BPS             : 64000
#       BPS-eng         : 64000
#       DURATION        : 00:42:32.192000000
#       DURATION-eng    : 00:42:32.192000000
#       NUMBER_OF_FRAMES: 59817
#       NUMBER_OF_FRAMES-eng: 59817
#       NUMBER_OF_BYTES : 20417537
#       NUMBER_OF_BYTES-eng: 20417537
#       _STATISTICS_WRITING_APP: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-28 19:21:55
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-28 19:21:55
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:2: Subtitle: subrip (default)
#     Metadata:
#       BPS             : 93
#       BPS-eng         : 93
#       DURATION        : 00:42:02.217000000
#       DURATION-eng    : 00:42:02.217000000
#       NUMBER_OF_FRAMES: 950
#       NUMBER_OF_FRAMES-eng: 950
#       NUMBER_OF_BYTES : 29609
#       NUMBER_OF_BYTES-eng: 29609
#       _STATISTICS_WRITING_APP: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-28 19:21:55
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-28 19:21:55
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Audio/Jane.the.Virgin.S01E04.Chapter.Four.720p.WEB-DL.2CH.x265.HEVC-PSAaudio.mp4':
#   Metadata:
#     title           : PSArips.com | Jane.the.Virgin.S01E04.Chapter.Four.720p.WEB-DL.2CH.x265.HEVC-PSA
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       title           : Stereo
#       BPS             : 64000
#       BPS-eng         : 64000
#       DURATION        : 00:42:32.192000000
#       DURATION-eng    : 00:42:32.192000000
#       NUMBER_OF_FRAMES: 59817
#       NUMBER_OF_FRAMES-eng: 59817
#       NUMBER_OF_BYTES : 20417537
#       NUMBER_OF_BYTES-eng: 20417537
#       _STATISTICS_WRITING_APP: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v7.9.0 ('Birds') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2015-05-28 19:21:55
#       _STATISTICS_WRITING_DATE_UTC-eng: 2015-05-28 19:21:55
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S01E04.Chapter.Four.720p.WEB-DL.2CH.x265.HEVC-PSA.mkv
# size=   20298kB time=00:42:32.14 bitrate=  65.2kbits/s speed=3.64e+03x
# video:0kB audio:19939kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.799272%
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S02E04.mkv
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S02E04.mkv':
#   Metadata:
#     encoder         : libebml v1.3.3 + libmatroska v1.4.4
#     creation_time   : 2016-06-18T05:01:47.000000Z
#   Duration: 00:41:30.59, start: 0.000000, bitrate: 1308 kb/s
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1280x720, SAR 1:1 DAR 16:9, 23.98 fps, 23.98 tbr, 1k tbn, 47.95 tbc (default)
#     Metadata:
#       BPS             : 1082963
#       BPS-eng         : 1082963
#       DURATION        : 00:41:30.530000000
#       DURATION-eng    : 00:41:30.530000000
#       NUMBER_OF_FRAMES: 59713
#       NUMBER_OF_FRAMES-eng: 59713
#       NUMBER_OF_BYTES : 337144020
#       NUMBER_OF_BYTES-eng: 337144020
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 05:01:47
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 05:01:47
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:1(eng): Audio: ac3, 48000 Hz, 5.1(side), fltp, 224 kb/s
#     Metadata:
#       BPS             : 224000
#       BPS-eng         : 224000
#       DURATION        : 00:41:30.592000000
#       DURATION-eng    : 00:41:30.592000000
#       NUMBER_OF_FRAMES: 77831
#       NUMBER_OF_FRAMES-eng: 77831
#       NUMBER_OF_BYTES : 69736576
#       NUMBER_OF_BYTES-eng: 69736576
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 05:01:47
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 05:01:47
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:2: Subtitle: subrip
#     Metadata:
#       BPS             : 93
#       BPS-eng         : 93
#       DURATION        : 00:41:23.441000000
#       DURATION-eng    : 00:41:23.441000000
#       NUMBER_OF_FRAMES: 1014
#       NUMBER_OF_FRAMES-eng: 1014
#       NUMBER_OF_BYTES : 29124
#       NUMBER_OF_BYTES-eng: 29124
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 05:01:47
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 05:01:47
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# [mp4 @ 0x563b0226a600] track 0: codec frame size is not set
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Audio/Jane.the.Virgin.S02E04audio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Audio: ac3 (ac-3 / 0x332D6361), 48000 Hz, 5.1(side), fltp, 224 kb/s
#     Metadata:
#       BPS             : 224000
#       BPS-eng         : 224000
#       DURATION        : 00:41:30.592000000
#       DURATION-eng    : 00:41:30.592000000
#       NUMBER_OF_FRAMES: 77831
#       NUMBER_OF_FRAMES-eng: 77831
#       NUMBER_OF_BYTES : 69736576
#       NUMBER_OF_BYTES-eng: 69736576
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 05:01:47
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 05:01:47
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   68103kB time=00:41:30.56 bitrate= 224.0kbits/s speed=1.82e+03x
# video:0kB audio:68102kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001402%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, matroska,webm, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S02E14.mkv':
#   Metadata:
#     encoder         : libebml v1.3.3 + libmatroska v1.4.4
#     creation_time   : 2016-06-18T13:31:28.000000Z
#   Duration: 00:41:49.12, start: 0.000000, bitrate: 1300 kb/s
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1280x720, SAR 1:1 DAR 16:9, 23.98 fps, 23.98 tbr, 1k tbn, 47.95 tbc (default)
#     Metadata:
#       BPS             : 1074093
#       BPS-eng         : 1074093
#       DURATION        : 00:41:49.090000000
#       DURATION-eng    : 00:41:49.090000000
#       NUMBER_OF_FRAMES: 60158
#       NUMBER_OF_FRAMES-eng: 60158
#       NUMBER_OF_BYTES : 336874534
#       NUMBER_OF_BYTES-eng: 336874534
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 13:31:28
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 13:31:28
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:1(eng): Audio: ac3, 48000 Hz, 5.1(side), fltp, 224 kb/s
#     Metadata:
#       BPS             : 224000
#       BPS-eng         : 224000
#       DURATION        : 00:41:49.120000000
#       DURATION-eng    : 00:41:49.120000000
#       NUMBER_OF_FRAMES: 78410
#       NUMBER_OF_FRAMES-eng: 78410
#       NUMBER_OF_BYTES : 70255360
#       NUMBER_OF_BYTES-eng: 70255360
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 13:31:28
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 13:31:28
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#     Stream #0:2: Subtitle: subrip
#     Metadata:
#       BPS             : 88
#       BPS-eng         : 88
#       DURATION        : 00:41:43.240000000
#       DURATION-eng    : 00:41:43.240000000
#       NUMBER_OF_FRAMES: 918
#       NUMBER_OF_FRAMES-eng: 918
#       NUMBER_OF_BYTES : 27684
#       NUMBER_OF_BYTES-eng: 27684
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 13:31:28
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 13:31:28
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# [mp4 @ 0x558e5e98a600] track 0: codec frame size is not set
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Audio/Jane.the.Virgin.S02E14audio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Audio: ac3 (ac-3 / 0x332D6361), 48000 Hz, 5.1(side), fltp, 224 kb/s
#     Metadata:
#       BPS             : 224000
#       BPS-eng         : 224000
#       DURATION        : 00:41:49.120000000
#       DURATION-eng    : 00:41:49.120000000
#       NUMBER_OF_FRAMES: 78410
#       NUMBER_OF_FRAMES-eng: 78410
#       NUMBER_OF_BYTES : 70255360
#       NUMBER_OF_BYTES-eng: 70255360
#       _STATISTICS_WRITING_APP: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_APP-eng: mkvmerge v9.0.1 ('Obstacles') 64bit
#       _STATISTICS_WRITING_DATE_UTC: 2016-06-18 13:31:28
#       _STATISTICS_WRITING_DATE_UTC-eng: 2016-06-18 13:31:28
#       _STATISTICS_TAGS: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
#       _STATISTICS_TAGS-eng: BPS DURATION NUMBER_OF_FRAMES NUMBER_OF_BYTES
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Jane_the_Virgin/Video/Jane.the.Virgin.S02E14.mkv
# size=   68610kB time=00:41:49.08 bitrate= 224.0kbits/s speed=1.89e+03x
# video:0kB audio:68609kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001398%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
# ...
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709/unknown/unknown), 720x404, 597 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2012-02-27T20:59:03.000000Z
#       handler_name    : GPAC ISO Video Handler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 143 kb/s (default)
#     Metadata:
#       creation_time   : 2012-02-26T22:16:30.000000Z
#       handler_name    : GPAC ISO Audio Handler
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Audio/Pretty.Little.Liars.S02E22.HDTV.x264-LOL.Father.Knows.Bestaudio.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 143 kb/s (default)
#     Metadata:
#       creation_time   : 2012-02-26T22:16:30.000000Z
#       handler_name    : GPAC ISO Audio Handler
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/Pretty.Little.Liars.S02E22.HDTV.x264-LOL.Father.Knows.Best.mp4
# size=   45907kB time=00:43:17.24 bitrate= 144.8kbits/s speed=3.24e+03x
# video:0kB audio:45429kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.050093%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/S01E17 The New Normal.avi':
#   Metadata:
#     encoder         : transcode-1.0.4
#   Duration: 00:41:36.26, start: 0.000000, bitrate: 1177 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 1002 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 128 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Audio/S01E17 The New Normalaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/S01E17 The New Normal.avi
# size=   49881kB time=00:41:36.24 bitrate= 163.7kbits/s speed=1.94e+03x
# video:0kB audio:49473kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.824238%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/Pretty.Little.Liars.S02E25.HDTV.x264-LOL.unmAsked.mp4
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/Pretty.Little.Liars.S02E25.HDTV.x264-LOL.unmAsked.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2012-03-18T17:41:55.000000Z
#   Duration: 00:43:41.41, start: 0.000000, bitrate: 945 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709/unknown/unknown), 720x404, 805 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2012-03-19T16:14:57.000000Z
#       handler_name    : GPAC ISO Video Handler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 136 kb/s (default)
#     Metadata:
#       creation_time   : 2012-03-18T17:41:58.000000Z
#       handler_name    : GPAC ISO Audio Handler
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Audio/Pretty.Little.Liars.S02E25.HDTV.x264-LOL.unmAskedaudio.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 136 kb/s (default)
#     Metadata:
#       creation_time   : 2012-03-18T17:41:58.000000Z
#       handler_name    : GPAC ISO Audio Handler
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   44137kB time=00:43:41.37 bitrate= 137.9kbits/s speed=3.11e+03x
# video:0kB audio:43655kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.102818%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/S01E10 Keep Your Friends Close.avi
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/S01E10 Keep Your Friends Close.avi':
#   Metadata:
#     encoder         : Nandub v1.0rc2
#   Duration: 00:43:36.41, start: 0.000000, bitrate: 1122 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 952 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 128 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Audio/S01E10 Keep Your Friends Closeaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# size=   50594kB time=00:43:36.38 bitrate= 158.4kbits/s speed=1.27e+03x
# video:0kB audio:50167kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.851849%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/Pretty.Little.Liars.S02E21.HDTV.XviD-LOL.Breaking.the.Code.avi':
#   Metadata:
#     encoder         : transcode-1.0.6
#   Duration: 00:43:51.34, start: 0.000000, bitrate: 1115 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 934 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 128 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Audio/Pretty.Little.Liars.S02E21.HDTV.XviD-LOL.Breaking.the.Codeaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/Pretty.Little.Liars.S02E21.HDTV.XviD-LOL.Breaking.the.Code.avi
# size=   54402kB time=00:43:50.80 bitrate= 169.4kbits/s speed=3.53e+03x
# video:0kB audio:53973kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.796224%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, avi, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/Pretty.Little.Liars.S02E17.HDTV.XviD-FQM.Blond.Leading.the.Blind.avi':
#   Metadata:
#     encoder         : transcode-1.0.4
#   Duration: 00:42:28.78, start: 0.000000, bitrate: 1153 kb/s
#     Stream #0:0: Video: mpeg4 (Advanced Simple Profile) (XVID / 0x44495658), yuv420p, 624x352 [SAR 1:1 DAR 39:22], 982 kb/s, 23.98 fps, 23.98 tbr, 23.98 tbn, 23.98 tbc
#     Stream #0:1: Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp, 128 kb/s
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Audio/Pretty.Little.Liars.S02E17.HDTV.XviD-FQM.Blond.Leading.the.Blindaudio.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Audio: mp3 (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/Pretty.Little.Liars.S02E17.HDTV.XviD-FQM.Blond.Leading.the.Blind.avi
# size=   49702kB time=00:42:28.75 bitrate= 159.7kbits/s speed=4.02e+03x
# video:0kB audio:49285kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.844699%
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/ada/anaconda3/envs/Python --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/Pretty.Little.Liars.S02E23.HDTV.x264-LOL.Eye.of.the.Beholder.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     creation_time   : 2012-03-04T21:44:07.000000Z
#   Duration: 00:43:36.87, start: 0.000000, bitrate: 775 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709/unknown/unknown), 720x404, 627 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2012-03-05T18:07:58.000000Z
#       handler_name    : GPAC ISO Video Handler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 143 kb/s (default)
#     Metadata:
#       creation_time   : 2012-03-04T21:44:15.000000Z
#       handler_name    : GPAC ISO Audio Handler
# Output #0, mp4, to '/home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Audio/Pretty.Little.Liars.S02E23.HDTV.x264-LOL.Eye.of.the.Beholderaudio.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isom
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 143 kb/s (default)
#     Metadata:
#       creation_time   : 2012-03-04T21:44:15.000000Z
#       handler_name    : GPAC ISO Audio Handler
# Stream mapping:
#   Stream #0:1 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# /home/ada/Documents/DTA/Thesis/Data/TV_shows/Women/Pretty_Little_Liars/Video/Pretty.Little.Liars.S02E23.HDTV.x264-LOL.Eye.of.the.Beholder.mp4
# size=   46398kB time=00:43:36.85 bitrate= 145.2kbits/s speed=1.97e+03x
# video:0kB audio:45917kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.046760%
